# %% [markdown]
# ## XGBoost 모델로 다음달 재고 예측하기
#
#
# - 참고: https://github.com/kroonstazy/Capstone_Project_2/blob/master/Notebooks/03_XGBoost_Cap_Project_2.ipynb

# %% [markdown]
# 생각
# - industry data로 다음 3달 예측 -> 어차피 우리 회사게 가장 먼저 팔리므로 가장 이윤이 많이 나오는 상품 순으로 개수 잘라서 분배하면 되지 않을까??

# %% [markdown]
# ### 1. Import and load data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings

from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.impute import SimpleImputer

from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit

from sklearn import preprocessing


from tqdm import tqdm

# %%
warnings.filterwarnings(action='ignore')

# %%
file_path = "./dataset_new/"
retail_data= pd.read_csv(f"{file_path}retail_all.csv") # outlier를 삭제한 데이터
industry_data= pd.read_csv(f"{file_path}industry_all.csv")
d_h= pd.read_csv(f"{file_path}Dealer_Hierarchies.csv")

# %%
d_h
# Out:
#      Store  Store Owner                     Region Level 1 Region Level 2  \
# 0        1            1                Eisenstadt-Umgebung            GWR
# 1        2            1         Politischer Bezirk Güssing            GWR
# 2        3            1     Politischer Bezirk Jennersdorf            GWR
# 3        4            1     Politischer Bezirk Jennersdorf            GWR
# 4        5            1  Politischer Bezirk Oberpullendorf            GWR
# ..     ...          ...                                ...            ...
# 637    638          132                         Graz Stadt            MMJ
# 638    639          300        Politischer Bezirk Eferding            ICA
# 639    640          301                            Benešov            UQM
# 640    641            4                  Nivala-Haapajärvi            IRA
# 641    642           74                         Koillismaa            KTR
#
#     Urban/Rural
# 0         Urban
# 1         Urban
# 2         Urban
# 3         Urban
# 4         Urban
# ..          ...
# 637       Rural
# 638       Rural
# 639       Rural
# 640       Urban
# 641       Urban
#
# [642 rows x 5 columns]

# %%
set_dt = "2022-06-01"

# %%
datetime_list = list(dict.fromkeys(list(industry_data['Datetime'])))
store_list = [i for i in range(1, 643)] # 1~642

# %%
product_dict = {"Power Cord":"Electronics",
                "Phone Charger":"Electronics",
                "Ear Buds":"Electronics",
                "Mouse":"Electronics",
                "Keyboard":"Electronics",
                "Milk":"Grocery",
                "Eggs":"Grocery",
                "Cereal":"Grocery",
                "Shrimp":"Grocery",
                "Noodles":"Grocery",
                "Steak":"Grocery",
                "King Crab":"Grocery",
                "Tape":"Home Goods",
                "Glue":"Home Goods",
                "Nails":"Home Goods",
                "Bracket":"Home Goods",
                "Brush":"Home Goods",
                "Paint":"Home Goods"
                }

# %%
retail_data
# Out:
#         Sales Total  Store Product Type           Item  Year  Month  \
# 0                 1      1  Electronics  Phone Charger  2021      2
# 1                 5      1      Grocery         Shrimp  2021      2
# 2                 2      1      Grocery        Noodles  2021      2
# 3                 1      1      Grocery      King Crab  2021      2
# 4                 1      1  Electronics       Ear Buds  2021      3
# ...             ...    ...          ...            ...   ...    ...
# 101820            1    642  Electronics       Ear Buds  2021      5
# 101821            0    642  Electronics       Ear Buds  2021      6
# 101822            1    642  Electronics       Ear Buds  2021      7
# 101823            1    642  Electronics       Keyboard  2022      2
# 101824            0    642      Grocery         Shrimp  2022      3
#
#           Datetime       Region Level 1 Region Level 2 Urban/Rural  Owner
# 0       2021-02-01  Eisenstadt-Umgebung            GWR       Urban      1
# 1       2021-02-01  Eisenstadt-Umgebung            GWR       Urban      1
# 2       2021-02-01  Eisenstadt-Umgebung            GWR       Urban      1
# 3       2021-02-01  Eisenstadt-Umgebung            GWR       Urban      1
# 4       2021-03-01  Eisenstadt-Umgebung            GWR       Urban      1
# ...            ...                  ...            ...         ...    ...
# 101820  2021-05-01           Koillismaa            KTR       Urban     74
# 101821  2021-06-01           Koillismaa            KTR       Urban     74
# 101822  2021-07-01           Koillismaa            KTR       Urban     74
# 101823  2022-02-01           Koillismaa            KTR       Urban     74
# 101824  2022-03-01           Koillismaa            KTR       Urban     74
#
# [101825 rows x 11 columns]

# %%
# 추가할 dataframe
new_df = pd.DataFrame(
    [],columns = ['Sales Total', 'Store', 'Product Type', 'Item', 'Year', 'Month','Datetime', 'Region Level 1', 'Region Level 2', 'Urban/Rural', 'Owner']
)

# %%
from re import S


def append_new_sentence(new_df, product,d,s):
    new_df.loc[len(new_df)] = [
        0, # sales total
        s, #store
        product_dict[product], #item
        product, #product type
        int(d[:4]), # year
        int(d[5:7]), # month
        d, # datetime
        d_h.loc[s-1]['Region Level 1'],
        d_h.loc[s-1]['Region Level 2'],
        d_h.loc[s-1]['Urban/Rural'],
        d_h.loc[s-1]['Store Owner']
    ]
# list1 = []
# list2 = []
# list3 = []
# list4 = []
# list5 = []
# list6 = []
# list7 = []
# list8 = []
# list9 = []
# list10 = []
# list11 = []

# def append_new_sentence(product,d,s):

#     list1.append(0) # sales total
#     list2.append(s) # store
#     list3.append(product_dict[product])
#     list4.append(product)
#     list5.append(int(d[:4]))
#     list6.append(int(d[5:7]))
#     list7.append(d)
#     list8.append(d_h.loc[s-1]['Region Level 1'])
#     list9.append(d_h.loc[s-1]['Region Level 2'])
#     list10.append(d_h.loc[s-1]['Urban/Rural'])
#     list11.append(d_h.loc[s-1]['Store Owner'])

# %%
# 재고 0인 행 목록에 추가
for d in tqdm(datetime_list):
    for product in list(product_dict.keys()): #key
        for s in store_list:
            datetime_df = industry_data[(industry_data['Datetime']==d)&(industry_data['Store']==s)] # 해당 datetime의 df
            if len(datetime_df[datetime_df['Item']==product])==0:
                append_new_sentence(new_df,product,d,s)

# %%
# 추가
retail_data_1_add0 = retail_data.append(new_df, ignore_index=True)

# 정렬 # 1,005,372 개여야함
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ubuntu/minji/Data-Science-Project/xgboost_retail.ipynb 셀 15 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bjaypark/home/ubuntu/minji/Data-Science-Project/xgboost_retail.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # 추가
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bjaypark/home/ubuntu/minji/Data-Science-Project/xgboost_retail.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> retail_data_1_add0 = retail_data.append(new_df, ignore_index=True)
#       <a href='vscode-notebook-cell://ssh-remote%2Bjaypark/home/ubuntu/minji/Data-Science-Project/xgboost_retail.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> # 정렬 # 1,005,372 개여야함
#       <a href='vscode-notebook-cell://ssh-remote%2Bjaypark/home/ubuntu/minji/Data-Science-Project/xgboost_retail.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> retail_data_1_add0.sort_values(['Datetime','Store','Item'],inplace=True)
#
# NameError: name 'new_df' is not defined

# %%
check = []

import math

for i in tqdm(range(len(retail_data_1_add0))):
    sales = retail_data_1_add0.loc[i]['Sales Total']
    industry = retail_data_1_add0.loc[i]['Industry Size']
    if math.isnan(sales):
        check.append(industry)
    else:
        check.append(sales)
# Out:
# 100%|██████████| 1005372/1005372 [03:26<00:00, 4859.75it/s]

# %%
check = list(map(int, check))

# %%
retail_data_1_add0['Sales Total'] = check
#retail_data_1_add0 = retail_data_1_add0.drop(['Industry Size'], axis = 1)

# %%
retail_data_1_add0
# Out:
#          Sales Total  Store Product Type     Item  Year  Month    Datetime  \
# 0                  0      1   Home Goods  Bracket  2015      1  2015-01-01
# 1                  0      2   Home Goods  Bracket  2015      1  2015-01-01
# 2                  0      3   Home Goods  Bracket  2015      1  2015-01-01
# 3                  0      4   Home Goods  Bracket  2015      1  2015-01-01
# 4                  0      5   Home Goods  Bracket  2015      1  2015-01-01
# ...              ...    ...          ...      ...   ...    ...         ...
# 1005367            0    638   Home Goods     Tape  2022      3  2022-03-01
# 1005368            0    639   Home Goods     Tape  2022      3  2022-03-01
# 1005369            0    640   Home Goods     Tape  2022      3  2022-03-01
# 1005370            0    641   Home Goods     Tape  2022      3  2022-03-01
# 1005371            0    642   Home Goods     Tape  2022      3  2022-03-01
#
#                             Region Level 1 Region Level 2 Urban/Rural  Owner
# 0                      Eisenstadt-Umgebung            GWR       Urban      1
# 1               Politischer Bezirk Güssing            GWR       Urban      1
# 2           Politischer Bezirk Jennersdorf            GWR       Urban      1
# 3           Politischer Bezirk Jennersdorf            GWR       Urban      1
# 4        Politischer Bezirk Oberpullendorf            GWR       Urban      1
# ...                                    ...            ...         ...    ...
# 1005367                         Graz Stadt            MMJ       Rural    132
# 1005368        Politischer Bezirk Eferding            ICA       Rural    300
# 1005369                            Benešov            UQM       Rural    301
# 1005370                  Nivala-Haapajärvi            IRA       Urban      4
# 1005371                         Koillismaa            KTR       Urban     74
#
# [1005372 rows x 11 columns]

# %%
retail_data_1_add0.to_csv('./retail_data_add0.csv',index=False)

# %%
retail_data_1_add0 = pd.read_csv('./dataset_new/retail_data_add0.csv')
retail_data_1_add0.sort_values(['Datetime','Store','Item'],inplace=True)
retail_data_1_add0.reset_index(drop=True,inplace=True)
retail_data_1_add0
# Out:
#          Sales Total  Store Product Type           Item  Year  Month  \
# 0                  0      1   Home Goods        Bracket  2015      1
# 1                  0      1   Home Goods          Brush  2015      1
# 2                  0      1      Grocery         Cereal  2015      1
# 3                  0      1  Electronics       Ear Buds  2015      1
# 4                  0      1      Grocery           Eggs  2015      1
# ...              ...    ...          ...            ...   ...    ...
# 1040035            0    642  Electronics  Phone Charger  2022      6
# 1040036            0    642  Electronics     Power Cord  2022      6
# 1040037            0    642      Grocery         Shrimp  2022      6
# 1040038            0    642      Grocery          Steak  2022      6
# 1040039            0    642   Home Goods           Tape  2022      6
#
#            Datetime       Region Level 1 Region Level 2 Urban/Rural  Owner
# 0        2015-01-01  Eisenstadt-Umgebung            GWR       Urban      1
# 1        2015-01-01  Eisenstadt-Umgebung            GWR       Urban      1
# 2        2015-01-01  Eisenstadt-Umgebung            GWR       Urban      1
# 3        2015-01-01  Eisenstadt-Umgebung            GWR       Urban      1
# 4        2015-01-01  Eisenstadt-Umgebung            GWR       Urban      1
# ...             ...                  ...            ...         ...    ...
# 1040035  2022-06-01           Koillismaa            KTR       Urban     74
# 1040036  2022-06-01           Koillismaa            KTR       Urban     74
# 1040037  2022-06-01           Koillismaa            KTR       Urban     74
# 1040038  2022-06-01           Koillismaa            KTR       Urban     74
# 1040039  2022-06-01           Koillismaa            KTR       Urban     74
#
# [1040040 rows x 11 columns]

# %%
set_dt = "2022-06-01"

# %%
# Label encoding

label = preprocessing.LabelEncoder()
retail_data_encoded = pd.DataFrame()

retail_data_1_col = ['Product Type', 'Item', 'Region Level 1', 'Region Level 2', 'Urban/Rural']
for i in retail_data_1_add0.columns:
    if i in retail_data_1_col:
        retail_data_encoded[i] = label.fit_transform(retail_data_1_add0[i])
    else:
        retail_data_encoded[i] = retail_data_1_add0[i]

# %%
retail_data_encoded
# Out:
#          Sales Total  Store  Product Type  Item  Year  Month    Datetime  \
# 0                  0      1             2     0  2015      1  2015-01-01
# 1                  0      1             2     1  2015      1  2015-01-01
# 2                  0      1             1     2  2015      1  2015-01-01
# 3                  0      1             0     3  2015      1  2015-01-01
# 4                  0      1             1     4  2015      1  2015-01-01
# ...              ...    ...           ...   ...   ...    ...         ...
# 1040035            0    642             0    13  2022      6  2022-06-01
# 1040036            0    642             0    14  2022      6  2022-06-01
# 1040037            0    642             1    15  2022      6  2022-06-01
# 1040038            0    642             1    16  2022      6  2022-06-01
# 1040039            0    642             2    17  2022      6  2022-06-01
#
#          Region Level 1  Region Level 2  Urban/Rural  Owner
# 0                    46               9            1      1
# 1                    46               9            1      1
# 2                    46               9            1      1
# 3                    46               9            1      1
# 4                    46               9            1      1
# ...                 ...             ...          ...    ...
# 1040035             137              21            1     74
# 1040036             137              21            1     74
# 1040037             137              21            1     74
# 1040038             137              21            1     74
# 1040039             137              21            1     74
#
# [1040040 rows x 11 columns]

# %%
sum(retail_data_encoded[retail_data_encoded['Year']==2020]['Sales Total'])/4
# Out:
# 6455.75

# %%
train_1 = retail_data_encoded[retail_data_encoded['Datetime'] < set_dt]
val_1 = retail_data_encoded[retail_data_encoded['Datetime'] >= set_dt] # 2022

# %%
# Feature와 Target 분리
target = 'Sales Total'
features = train_1.drop([target,"Datetime"], axis=1).columns

X_train = train_1[features]
y_train = train_1[target]
X_val = val_1[features]
y_val = val_1[target]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (1028484, 9) (1028484,)
# (11556, 9) (11556,)

# %%
# 확인
X_train.head(3)
# Out:
#    Store  Product Type  Item  Year  Month  Region Level 1  Region Level 2  \
# 0      1             2     0  2015      1              46               9
# 1      1             2     1  2015      1              46               9
# 2      1             1     2  2015      1              46               9
#
#    Urban/Rural  Owner
# 0            1      1
# 1            1      1
# 2            1      1

# %%
# 파이프라인 생성 및 학습
xgb_basic = make_pipeline(
    SimpleImputer(),
    RobustScaler(),
    XGBRegressor(random_state=1,
                 n_jobs=-1,
                 objective='reg:squarederror',
                 max_depth=5, # 5
                 learning_rate=0.2))

xgb_basic.fit(X_train, y_train);

# %%
# 예측
y_pred = xgb_basic.predict(X_val)

# prediction값 반올림
y_pred_r =  [round(x) if round(x) >=0 else 0 for x in y_pred]

# 결과 확인

print('mae:  ', mae(y_val, y_pred_r))
print('rmse: ', np.sqrt(mse(y_val, y_pred_r)))

# 수정전
# mae:   0.5681168738391199
# rmse:  1.5965796357571027
# Out:
# mae:   0.02215299411561094
# rmse:  0.1539825526297211

# %%
plt.figure(figsize=(20, 4))

plt.plot(retail_data_encoded[retail_data_encoded['Datetime'] >= set_dt]['Sales Total'].reset_index(drop=True), label='Actual',)
plt.plot(y_pred_r, label='Predicted')



plt.legend()
plt.show();

# %%
sum(y_pred_r)
# Out:
# 256

# %%
# 빈값에 예측값 추가
newlist = list(retail_data_encoded[retail_data_encoded['Datetime']<set_dt]['Sales Total'])+y_pred_r
retail_data_encoded['Sales Total'] = newlist

# %%
# result = pd.DataFrame([])
#result['predicted'] = y_pred_r
result = retail_data_encoded[retail_data_encoded['Datetime']>=set_dt]['Sales Total']
result.to_csv("1111_retail.csv",index=False)

# %% [markdown]
# 쫌..구리다!
#
#
# ### hyper parameter

# %%
# eval set 생성
pre_processing_part = make_pipeline(
    SimpleImputer(),
    RobustScaler())

X_train_processing = pre_processing_part.fit_transform(X_train)
X_val_processing = pre_processing_part.transform(X_val)

eval_set = [(X_train_processing, y_train),
            (X_val_processing, y_val)]

# %%
# 모델 생성
xgb_hyper = XGBRegressor(
    random_state=1,
    n_jobs=-1,
    objective='reg:squarederror')

# 사용할 하이퍼 파라미터
dists = {
    'max_depth': [3, 4, 5, 6, 7, 8],
    'min_child_weight': [1, 2, 3, 4],
    'gamma': [0, 0.01, 0.1, 0.2, 0.3],
    'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.3]}

# cv
cv = TimeSeriesSplit(n_splits=5)

# GridSearchCV
reg_xgb_hyper = GridSearchCV(
    xgb_hyper, 
    param_grid=dists,
    cv=cv, 
    scoring='neg_root_mean_squared_error',
    verbose=0,
    n_jobs=-1
)

reg_xgb_hyper.fit(X_train_processing,
                  y_train,
                  eval_set = eval_set,
                  eval_metric='rmse',
                  early_stopping_rounds = 50);

# %%
# 결과 확인
print('best hyper-parameter: ', reg_xgb_hyper.best_params_)
# Out:
# best hyper-parameter:  {'gamma': 0.01, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 4}

# %%
# cv 결과 확인
pd.DataFrame(reg_xgb_hyper.cv_results_).sort_values(by='rank_test_score').head().T
# Out:
#                                                                       219  \
# mean_fit_time                                                    0.047009
# std_fit_time                                                     0.008574
# mean_score_time                                                  0.002013
# std_score_time                                                   0.000043
# param_gamma                                                          0.01
# param_learning_rate                                                   0.3
# param_max_depth                                                         3
# param_min_child_weight                                                  4
# params                  {'gamma': 0.01, 'learning_rate': 0.3, 'max_dep...
# split0_test_score                                               -0.370669
# split1_test_score                                               -0.485845
# split2_test_score                                               -0.655306
# split3_test_score                                               -0.560952
# split4_test_score                                               -0.842688
# mean_test_score                                                 -0.583092
# std_test_score                                                   0.159797
# rank_test_score                                                         1
#
#                                                                       99   \
# mean_fit_time                                                     0.08692
# std_fit_time                                                     0.058549
# mean_score_time                                                  0.001905
# std_score_time                                                   0.000063
# param_gamma                                                             0
# param_learning_rate                                                   0.3
# param_max_depth                                                         3
# param_min_child_weight                                                  4
# params                  {'gamma': 0, 'learning_rate': 0.3, 'max_depth'...
# split0_test_score                                               -0.370669
# split1_test_score                                               -0.485809
# split2_test_score                                               -0.655525
# split3_test_score                                               -0.560949
# split4_test_score                                               -0.842688
# mean_test_score                                                 -0.583128
# std_test_score                                                   0.159821
# rank_test_score                                                         2
#
#                                                                       75   \
# mean_fit_time                                                    0.044571
# std_fit_time                                                     0.005112
# mean_score_time                                                  0.001986
# std_score_time                                                   0.000076
# param_gamma                                                             0
# param_learning_rate                                                   0.2
# param_max_depth                                                         3
# param_min_child_weight                                                  4
# params                  {'gamma': 0, 'learning_rate': 0.2, 'max_depth'...
# split0_test_score                                               -0.382337
# split1_test_score                                               -0.491239
# split2_test_score                                               -0.650414
# split3_test_score                                               -0.549979
# split4_test_score                                                -0.84184
# mean_test_score                                                 -0.583162
# std_test_score                                                   0.155768
# rank_test_score                                                         3
#
#                                                                       463  \
# mean_fit_time                                                    0.046868
# std_fit_time                                                      0.01084
# mean_score_time                                                  0.002096
# std_score_time                                                   0.000365
# param_gamma                                                           0.2
# param_learning_rate                                                   0.3
# param_max_depth                                                         4
# param_min_child_weight                                                  4
# params                  {'gamma': 0.2, 'learning_rate': 0.3, 'max_dept...
# split0_test_score                                               -0.388187
# split1_test_score                                                -0.49675
# split2_test_score                                               -0.666322
# split3_test_score                                                -0.54538
# split4_test_score                                               -0.822533
# mean_test_score                                                 -0.583834
# std_test_score                                                   0.149078
# rank_test_score                                                         4
#
#                                                                       339
# mean_fit_time                                                    0.039924
# std_fit_time                                                      0.00674
# mean_score_time                                                  0.001984
# std_score_time                                                   0.000224
# param_gamma                                                           0.1
# param_learning_rate                                                   0.3
# param_max_depth                                                         3
# param_min_child_weight                                                  4
# params                  {'gamma': 0.1, 'learning_rate': 0.3, 'max_dept...
# split0_test_score                                               -0.376114
# split1_test_score                                               -0.485032
# split2_test_score                                               -0.655636
# split3_test_score                                               -0.559222
# split4_test_score                                               -0.843774
# mean_test_score                                                 -0.583956
# std_test_score                                                   0.158896
# rank_test_score                                                         5

# %%
# 모델 저장
model_xgb_hyper = reg_xgb_hyper.best_estimator_

# 예측
y_pred = model_xgb_hyper.predict(X_val_processing)

# prediction값 반올림
y_pred_r =  [round(x) if round(x) >=0 else 0 for x in y_pred]

# 결과 정리
print('mae :', round(mae(y_val, y_pred_r), 2))
print('rmse :', round(np.sqrt(mse(y_val, y_pred_r)), 2))
# Out:
# mae : 0.37
# rmse : 0.71

# %%
plt.figure(figsize=(20, 4))
plt.plot(industry_data_encoded[industry_data_encoded['Datetime'] >= set_dt]['Industry Size'].reset_index(drop=True), label='Actual',)
plt.plot(y_pred_r, label='Predicted')


plt.legend()
plt.show();
